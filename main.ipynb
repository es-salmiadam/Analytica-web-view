# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv('dataset.csv')
print(data)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_29144\32628910.py:1: DtypeWarning: Columns (5,7,18,21,22,23,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   data= pd.read_csv('dataset.csv')
#                                                       url  \
# 0       https://twitter.com/LaTera__/status/1477429429...
# 1       https://twitter.com/allirica_rose/status/14774...
# 2       https://twitter.com/matrixlms/status/147742942...
# 3       https://twitter.com/AnarkyIsMe/status/14774294...
# 4       https://twitter.com/__amyya/status/14774294292...
# ...                                                   ...
# 547491                                                NaN
# 547492                                                NaN
# 547493                                                NaN
# 547494                                                NaN
# 547495                                                NaN
#
#                              date  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547496 entries, 0 to 547495
# Data columns (total 28 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   url                  547484 non-null  object
#  1   date                 547484 non-null  object
#  2   content              547484 non-null  object
#  3   likeCount            547484 non-null  float64
#  4   replyCount           547484 non-null  float64
#  5   retweetCount         547484 non-null  object
#  6   viewCount            547484 non-null  float64
#  7   quoteCount           547484 non-null  object
#  8   sourceLabel          547481 non-null  object
#  9   links                54495 non-null   object
#  10  media                154208 non-null  object
#  11  quotedTweet          123546 non-null  object
#  12  mentionedUsers       75874 non-null   object
#  13  coordinates          15361 non-null   object
# ...

# %%
data.shape
# Out:
# (547496, 28)

# %%
data.head(10)
# Out:
#                                                  url  \
# 0  https://twitter.com/LaTera__/status/1477429429...
# 1  https://twitter.com/allirica_rose/status/14774...
# 2  https://twitter.com/matrixlms/status/147742942...
# 3  https://twitter.com/AnarkyIsMe/status/14774294...
# 4  https://twitter.com/__amyya/status/14774294292...
# 5  https://twitter.com/LiweiChen/status/147742942...
# 6  https://twitter.com/KellyWileyNews/status/1477...
# 7  https://twitter.com/HaruCosplay6/status/147742...
# 8  https://twitter.com/bleudawn7/status/147742942...
# 9  https://twitter.com/notyourjulz/status/1477429...
#
#                         date  \
# 0  2022-01-01 23:59:59+00:00
# 1  2022-01-01 23:59:59+00:00
# 2  2022-01-01 23:59:59+00:00
# 3  2022-01-01 23:59:59+00:00
# 4  2022-01-01 23:59:59+00:00
# 5  2022-01-01 23:59:59+00:00
# 6  2022-01-01 23:59:59+00:00
# 7  2022-01-01 23:59:59+00:00
# 8  2022-01-01 23:59:59+00:00
# 9  2022-01-01 23:59:59+00:00
#
# ...

# %%
# 1) Convertir la date en vrai datetime
data["Timestamp"] = pd.to_datetime(data["Timestamp"])

# 2) Créer une colonne Date (jour)
data["Date"] = data["Timestamp"].dt.date

# 3) Vérifier quelques infos
print("Nombre de lignes :", len(data))
print(data[["Tweet", "Sentiment", "Timestamp", "Retweets", "Likes"]].head(5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
# ...

# %%
tweets_par_jour = data.groupby("Date").size().reset_index(name="Nb_Tweets")
tweets_par_jour.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tweets_par_jour = data.groupby("Date").size().reset_index(name="Nb_Tweets")
#       2 tweets_par_jour.head()
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# ...
